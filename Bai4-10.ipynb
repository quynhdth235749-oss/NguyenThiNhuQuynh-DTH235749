# %%
print('Chao cac ban!')
# Out:
# Chao cac ban!

# %%
print('Nguyen Thi Nhu Quynh')
# Out:
# Nguyen Thi Nhu Quynh

# %%
print('Minh ve minh co nho ta \nMuoi lam nam ay thiet tha man nong. \nMinh ve minh co nho khong? \nNhin cay nho nui, nhin song nho nguon.')
# Out:
# Minh ve minh co nho ta
# Muoi lam nam ay thiet tha man nong.
# Minh ve minh co nho khong?
# Nhin cay nho nui, nhin song nho nguon.

# %%
print('Toi la AI')
# Out:
# Toi la AI

# %%
print('****')
print('\n*  *')
print('\n*  *')
print('\n****')
# Out:
# ****
#
# *  *
#
# *  *
#
# ****

# %%
print('*********')
print('\n*********')
print('\n*********')
print('\n*********')
# Out:
# *********
#
# *********
#
# *********
#
# *********

# %%
print('    *')
print('   ***')
print(' *******')
print('   ***')
print('  *****')
print('***********')
print('   * *')
print('   * *')
# Out:
#     *
#    ***
#  *******
#    ***
#   *****
# ***********
#    * *
#    * *
